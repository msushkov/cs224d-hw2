# %% [markdown]
# # CS 224D Assignment #2
# # Part [1]: Deep Networks: NER Window Model
#
# For this first part of the assignment, you'll build your first "deep" networks. On problem set 1, you computed the backpropagation gradient $\frac{\partial J}{\partial w}$ for a two-layer network; in this problem set you'll implement a slightly more complex network to perform  named entity recognition (NER).
#
# Before beginning the programming section, you should complete parts (a) and (b) of the corresponding section of the handout.

# %%
import sys, os
from numpy import *
from matplotlib.pyplot import *
# %matplotlib inline
matplotlib.rcParams['savefig.dpi'] = 100

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## (c): Random Initialization Test
# Use the cell below to test your code.

# %%
from misc import random_weight_matrix
random.seed(10)
print random_weight_matrix(3,5)
# Out:
# [[ 0.46994114 -0.83008197  0.23148553  0.43094097 -0.00258593]
#  [-0.47666619 -0.52297046  0.45125243 -0.57311684 -0.71301636]
#  [ 0.32105262  0.78530031 -0.85918681  0.02111762  0.54147539]]

# %% [markdown]
# ## (d): Implementation
#
# We've provided starter code to load in the dataset and convert it to a list of "windows", consisting of indices into the matrix of word vectors.
#
# We pad each sentence with begin and end tokens `<s>` and `</s>`, which have their own word vector representations; additionally, we convert all words to lowercase, canonicalize digits (e.g. `1.12` becomes `DG.DGDG`), and replace unknown words with a special token `UUUNKKK`.
#
# You don't need to worry about the details of this, but you can inspect the `docs` variables or look at the raw data (in plaintext) in the `./data/` directory.

# %%
import data_utils.utils as du
import data_utils.ner as ner

# %%
# Load the starter word vectors
wv, word_to_num, num_to_word = ner.load_wv('data/ner/vocab.txt',
                                           'data/ner/wordVectors.txt')
tagnames = ["O", "LOC", "MISC", "ORG", "PER"]
num_to_tag = dict(enumerate(tagnames))
tag_to_num = du.invert_dict(num_to_tag)

# Load the training set
docs = du.load_dataset('data/ner/train')
X_train, y_train = du.docs_to_windows(docs, word_to_num, tag_to_num)

# Load the dev set (for tuning hyperparameters)
docs = du.load_dataset('data/ner/dev')
X_dev, y_dev = du.docs_to_windows(docs, word_to_num, tag_to_num)

# Load the test set (dummy labels only)
docs = du.load_dataset('data/ner/test.masked')
X_test, y_test = du.docs_to_windows(docs, word_to_num, tag_to_num)

# %% [markdown]
# To avoid re-inventing the wheel, we provide a base class that handles a lot of the drudgery of managing parameters and running gradient descent. It's based on the classifier API used by [`scikit-learn`](http://scikit-learn.org/stable/), so if you're familiar with that library it should be easy to use.
#
# We'll be using this class for the rest of this assignment, so it helps to get acquainted with a simple example that should be familiar from Assignment 1. To keep this notebook uncluttered, we've put the code in the `softmax_example.py`; take a look at it there, then run the cell below.

# %%
from softmax_example import SoftmaxRegression
sr = SoftmaxRegression(wv=zeros((10,100)), dims=(100,5))

##
# Automatic gradient checker!
# this checks anything you add to self.grads or self.sgrads
# using the method of Assignment 1
sr.grad_check(x=5, y=4)
# Out:
# grad_check: dJ/db error norm = 3.555e-10 [ok]
#     b dims: [5] = 5 elem
# grad_check: dJ/dW error norm = 1.725e-11 [ok]
#     W dims: [5, 100] = 500 elem
# grad_check: dJ/dL[5] error norm = 2.433e-11 [ok]
#     L[5] dims: [100] = 100 elem

# %% [markdown]
# In order to implement a model, you need to subclass `NNBase`, then implement the following methods:
#
# - `__init__()` (initialize parameters and hyperparameters)
# - `_acc_grads()` (compute and accumulate gradients)
# - `compute_loss()` (compute loss for a training example)
# - `predict()`, `predict_proba()`, or other prediction method (for evaluation)
#
# `NNBase` provides you with a few others that will be helpful:
#
# - `grad_check()` (run a gradient check - calls `_acc_grads` and `compute_loss`)
# - `train_sgd()` (run SGD training; more on this later)
#
# Your task is to implement the window model in `nerwindow.py`; a scaffold has been provided for you with instructions on what to fill in.
#
# When ready, you can test below:

# %%
from nerwindow import WindowMLP
clf = WindowMLP(wv, windowsize=3, dims=[None, 100, 5],
                reg=0.001, alpha=0.01)
clf.grad_check(X_train[0], y_train[0]) # gradient check on single point
# Out:
# grad_check: dJ/db2 error norm = 3.14e-10 [ok]
#     b2 dims: [5] = 5 elem
# grad_check: dJ/dU error norm = 5.616e-10 [ok]
#     U dims: [5, 100] = 500 elem
# grad_check: dJ/db1 error norm = 2.868e-09 [ok]
#     b1 dims: [100] = 100 elem
# grad_check: dJ/dW error norm = 1.576e-08 [ok]
#     W dims: [100, 150] = 15000 elem
# grad_check: dJ/dL[12637] error norm = 2.997e-11 [ok]
#     L[12637] dims: [50, 1] = 50 elem
# grad_check: dJ/dL[445] error norm = 3.148e-11 [ok]
#     L[445] dims: [50, 1] = 50 elem
# grad_check: dJ/dL[977] error norm = 3.691e-11 [ok]
#     L[977] dims: [50, 1] = 50 elem

# %% [markdown]
# Now we'll train your model on some data! You can implement your own SGD method, but we recommend that you just call `clf.train_sgd`. This takes the following arguments:
#
# - `X`, `y` : training data
# - `idxiter`: iterable (list or generator) that gives index (row of X) of training examples in the order they should be visited by SGD
# - `printevery`: int, prints progress after this many examples
# - `costevery`: int, computes mean loss after this many examples. This is a costly operation, so don't make this too frequent!
#
# The implementation we give you supports minibatch learning; if `idxiter` is a list-of-lists (or yields lists), then gradients will be computed for all indices in a minibatch before modifying the parameters (this is why we have you write `_acc_grad` instead of applying them directly!).
#
# Before training, you should generate a training schedule to pass as `idxiter`. If you know how to use Python generators, we recommend those; otherwise, just make a static list. Make the following in the cell below:
#
# - An "epoch" schedule that just iterates through the training set, in order, `nepoch` times.
# - A random schedule of `N` examples sampled with replacement from the training set.
# - A random schedule of `N/k` minibatches of size `k`, sampled with replacement from the training set.

# %%
nepoch = 5
N = nepoch * len(y_train)
k = 5 # minibatch size

random.seed(10) # do not change this!
#### YOUR CODE HERE ####

indices = range(len(y_train))

# An "epoch" schedule that just iterates through the training set, in order, nepoch times
idxiter_epoch = nepoch * indices

# A random schedule of N examples sampled with replacement from the training set.
idxiter_N = random.choice(indices, N)

# A random schedule of N/k minibatches of size k, sampled with replacement from the training set.
def idxiter_batches():
    num_batches = N / k
    for i in xrange(num_batches):
        yield random.choice(indices, k)

#### END YOUR CODE ###

# %%
clf.train_sgd(X=X_train[:100000], y=y_train[:100000], idxiter=xrange(100000), printevery=5000, costevery=5000)
# Out:
# Begin SGD...
#   Seen 0 in 0.00 s
#   [0]: mean loss 1.77621
#   Seen 5000 in 24.27 s
#   [5000]: mean loss 0.546269
#   Seen 10000 in 41.69 s
#   [10000]: mean loss 0.49793
#   Seen 15000 in 58.30 s
#   [15000]: mean loss 0.534253
#   Seen 20000 in 80.89 s
#   [20000]: mean loss 0.433418
#   Seen 25000 in 103.78 s
#   [25000]: mean loss 0.460682
#   Seen 30000 in 127.62 s
#   [30000]: mean loss 0.458351
#   Seen 35000 in 149.81 s
#   [35000]: mean loss 0.78072
#   Seen 40000 in 169.13 s
#   [40000]: mean loss 0.47825
#   Seen 45000 in 186.25 s
#   [45000]: mean loss 0.431374
#   Seen 50000 in 206.60 s
#   [50000]: mean loss 0.484219
#   Seen 55000 in 227.30 s
#   [55000]: mean loss 0.508587
#   Seen 60000 in 246.68 s
#   [60000]: mean loss 0.400442
#   Seen 65000 in 263.47 s
#   [65000]: mean loss 0.572783
#   Seen 70000 in 278.20 s
#   [70000]: mean loss 0.541967
#   Seen 75000 in 290.66 s
#   [75000]: mean loss 0.390486
#   Seen 80000 in 303.52 s
#   [80000]: mean loss 0.382682
#   Seen 85000 in 320.34 s
#   [85000]: mean loss 0.371735
#   Seen 90000 in 336.07 s
#   [90000]: mean loss 0.407171
#   Seen 95000 in 352.55 s
#   [95000]: mean loss 0.387726
#   [100000]: mean loss 0.35368
# SGD complete: 100000 examples in 380.06 seconds.
# [(0, 1.7762140406391631),
#  (5000, 0.54626862473119731),
#  (10000, 0.49793003451316603),
#  (15000, 0.53425331563420686),
#  (20000, 0.43341751372442161),
#  (25000, 0.4606815350789446),
#  (30000, 0.45835145641684177),
#  (35000, 0.78072034636625309),
#  (40000, 0.47825015497047579),
#  (45000, 0.43137423067556752),
#  (50000, 0.48421901499661574),
#  (55000, 0.50858712630116032),
#  (60000, 0.40044153643090796),
#  (65000, 0.57278341962897683),
#  (70000, 0.54196741575297547),
#  (75000, 0.39048602712910752),
#  (80000, 0.38268184190804744),
#  (85000, 0.37173472631305488),
#  (90000, 0.40717088632536097),
#  (95000, 0.38772595068747751),
#  (100000, 0.35367979632220814)]

# %% [markdown]
# Now call `train_sgd` to train on `X_train`, `y_train`. To verify that things work, train on 100,000 examples or so to start (with any of the above schedules). This shouldn't take more than a couple minutes, and you should get a mean cross-entropy loss around 0.4.
#
# Now, if this works well, it's time for production! You have three tasks here:
#
# 1. Train a good model
# 2. Plot a learning curve (cost vs. # of iterations)
# 3. Use your best model to predict the test set
#
# You should train on the `train` data and evaluate performance on the `dev` set. The `test` data we provided has only dummy labels (everything is `O`); we'll compare your predictions to the true labels at grading time.
#
# Scroll down to section (f) for the evaluation code.
#
# We don't expect you to spend too much time doing an exhaustive search here; the default parameters should work well, although you can certainly do better. Try to achieve an F1 score of at least 76% on the dev set, as reported by `eval_performance`.
#
# Feel free to create new cells and write new code here, including new functions (helpers and otherwise) in `nerwindow.py`. When you have a good model, follow the instructions below to make predictions on the test set.
#
# A strong model may require 10-20 passes (or equivalent number of random samples) through the training set and could take 20 minutes or more to train - but it's also possible to be much, much faster!
#
# Things you may want to tune:
# - `alpha` (including using an "annealing" schedule to decrease the learning rate over time)
# - training schedule and minibatch size
# - regularization strength
# - hidden layer dimension
# - width of context window

# %%
#### YOUR CODE HERE ####
# Sandbox: build a good model by tuning hyperparameters

from nerwindow import full_report, eval_performance

# Tune training schedule
schedules = [idxiter_epoch, idxiter_N, idxiter_batches()]

for i, train_sched in enumerate(schedules):
    print "===== Training schedule %d:" % i
    clf = WindowMLP(wv, windowsize=3, dims=[None, 100, 5], reg=0.001, alpha=0.01)
    clf.train_sgd(X=X_train, y=y_train, idxiter=train_sched, printevery=250000, costevery=25000)
    yp = clf.predict(X_dev)
    full_report(y_dev, yp, tagnames)
    eval_performance(y_dev, yp, tagnames)

#### END YOUR CODE ####
# Out:
# ===== Training schedule 0:
# Begin SGD...
#   Seen 0 in 0.00 s
#   [0]: mean loss 1.77988
#   [25000]: mean loss 0
#   [1000000]: mean loss 0.145681
#   [1018105]: mean loss 0.151669
# SGD complete: 1018105 examples in 1771.35 seconds.
#              precision    recall  f1-score   support
#
#           O       0.94      0.99      0.97     42759
#         LOC       0.89      0.76      0.82      2094
#        MISC       0.84      0.63      0.72      1268
#         ORG       0.70      0.54      0.61      2092
#         PER       0.91      0.61      0.73      3149
#
# avg / total       0.93      0.93      0.93     51362
#
# === Performance (omitting 'O' class) ===
# Mean precision:  84.49%
# Mean recall:     63.25%
# Mean F1:         72.19%
# ===== Training schedule 2:
# Begin SGD...
#   Seen 0 in 0.31 s
#   [0]: mean loss 1.77988
#   [25000]: mean loss 0.282987
#   [50000]: mean loss 0.238369
#   [75000]: mean loss 0.201994
#   [100000]: mean loss 0.185012
#   [125000]: mean loss 0.183773
#   [150000]: mean loss 0.163939
#   [175000]: mean loss 0.153696
#   [200000]: mean loss 0.147178
#   [203621]: mean loss 0.149802
# SGD complete: 203621 examples in 4679.60 seconds.
#              precision    recall  f1-score   support
#
#           O       0.96      0.98      0.97     42759
#         LOC       0.91      0.71      0.80      2094
#        MISC       0.83      0.61      0.70      1268
#         ORG       0.63      0.61      0.62      2092
#         PER       0.83      0.82      0.82      3149
#
# avg / total       0.94      0.94      0.94     51362
#
# === Performance (omitting 'O' class) ===
# Mean precision:  80.09%
# Mean recall:     71.14%
# Mean F1:         75.06%
# nn/base.py:386: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if idxiter == None: # default training schedule

# %%
#### YOUR CODE HERE ####
# Sandbox: build a good model by tuning hyperparameters

# training schedule 2 is the best: N/k batches of size k

from nerwindow import full_report, eval_performance

# tune regularization strength
regs = [0.001, 0.005, 0.01, 0.0005, 0.0001]

for i, reg_val in enumerate(regs):
    print "===== Regularization %f:" % reg_val
    clf = WindowMLP(wv, windowsize=3, dims=[None, 100, 5], reg=reg_val, alpha=0.01)
    clf.train_sgd(X=X_train, y=y_train, idxiter=idxiter_batches(), printevery=100000, costevery=100000)
    yp = clf.predict(X_dev)
    full_report(y_dev, yp, tagnames)
    eval_performance(y_dev, yp, tagnames)


#### END YOUR CODE ####
# Out:
# ===== Regularization 0.001000:
# Begin SGD...
#   Seen 0 in 0.44 s
#   [0]: mean loss 1.77988
#   Seen 100000 in 2158.42 s
#   [100000]: mean loss 0.185012
#   Seen 200000 in 4243.81 s
#   [200000]: mean loss 0.147178
#   [203621]: mean loss 0.149802
# SGD complete: 203621 examples in 4360.21 seconds.
#              precision    recall  f1-score   support
#
#           O       0.96      0.98      0.97     42759
#         LOC       0.91      0.71      0.80      2094
#        MISC       0.83      0.61      0.70      1268
#         ORG       0.63      0.61      0.62      2092
#         PER       0.83      0.82      0.82      3149
#
# avg / total       0.94      0.94      0.94     51362
#
# === Performance (omitting 'O' class) ===
# Mean precision:  80.09%
# Mean recall:     71.14%
# Mean F1:         75.06%
# ===== Regularization 0.005000:
# Begin SGD...
#   Seen 0 in 0.03 s
#   [0]: mean loss 1.77988
#   Seen 100000 in 2102.45 s
#   [100000]: mean loss 0.252064
#   Seen 200000 in 4182.82 s
#   [200000]: mean loss 0.225933
#   [203621]: mean loss 0.220122
# SGD complete: 203621 examples in 4302.93 seconds.
#              precision    recall  f1-score   support
#
#           O       0.95      0.99      0.97     42759
#         LOC       0.93      0.58      0.71      2094
#        MISC       0.85      0.53      0.66      1268
#         ORG       0.51      0.50      0.51      2092
#         PER       0.78      0.66      0.71      3149
#
# avg / total       0.92      0.92      0.91     51362
#
# === Performance (omitting 'O' class) ===
# Mean precision:  76.17%
# Mean recall:     58.24%
# Mean F1:         65.50%
# ===== Regularization 0.010000:
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 1.77988
#   Seen 100000 in 2107.44 s
#   [100000]: mean loss 0.289391
#   Seen 200000 in 4196.90 s
#   [200000]: mean loss 0.266601
#   [203621]: mean loss 0.257696
# SGD complete: 203621 examples in 4331.27 seconds.
#              precision    recall  f1-score   support
#
#           O       0.93      0.99      0.96     42759
#         LOC       0.90      0.58      0.70      2094
#        MISC       0.83      0.49      0.61      1268
#         ORG       0.52      0.37      0.43      2092
#         PER       0.76      0.61      0.68      3149
#
# avg / total       0.90      0.91      0.90     51362
#
# === Performance (omitting 'O' class) ===
# Mean precision:  74.84%
# Mean recall:     52.35%
# Mean F1:         61.41%
# ===== Regularization 0.000500:
# Begin SGD...
#   Seen 0 in 0.04 s
#   [0]: mean loss 1.77988
#   Seen 100000 in 2093.51 s
#   [100000]: mean loss 0.165372
#   Seen 200000 in 4189.43 s
#   [200000]: mean loss 0.129976
#   [203621]: mean loss 0.130073
# SGD complete: 203621 examples in 4306.90 seconds.
#              precision    recall  f1-score   support
#
#           O       0.97      0.98      0.98     42759
#         LOC       0.91      0.76      0.83      2094
#        MISC       0.87      0.64      0.74      1268
#         ORG       0.69      0.63      0.66      2092
#         PER       0.82      0.84      0.83      3149
#
# avg / total       0.94      0.94      0.94     51362
#
# === Performance (omitting 'O' class) ===
# Mean precision:  82.07%
# Mean recall:     74.25%
# Mean F1:         77.71%
# ===== Regularization 0.000100:
# Begin SGD...
#   Seen 0 in 0.03 s
#   [0]: mean loss 1.77988
#   Seen 100000 in 2125.12 s
#   [100000]: mean loss 0.141716
#   Seen 200000 in 4272.33 s
#   [200000]: mean loss 0.105049
#   [203621]: mean loss 0.107211
# SGD complete: 203621 examples in 4392.30 seconds.
#              precision    recall  f1-score   support
#
#           O       0.97      0.98      0.98     42759
#         LOC       0.91      0.80      0.85      2094
#        MISC       0.83      0.71      0.76      1268
#         ORG       0.72      0.64      0.67      2092
#         PER       0.84      0.86      0.85      3149
#
# avg / total       0.95      0.95      0.95     51362
#
# === Performance (omitting 'O' class) ===
# Mean precision:  82.33%
# Mean recall:     76.89%
# Mean F1:         79.39%

# %%
#### YOUR CODE HERE ####
# Sandbox: build a good model by tuning hyperparameters

from nerwindow import full_report, eval_performance

# the best regularization value is 0.000100
best_reg = 0.000100

# tune hidden layer size

sizes = [150, 200, 300]

for i, size in enumerate(sizes):
    print "===== Hidden layer size %d:" % size
    clf = WindowMLP(wv, windowsize=3, dims=[None, size, 5], reg=best_reg, alpha=0.01)
    clf.train_sgd(X=X_train, y=y_train, idxiter=idxiter_batches(), printevery=100000, costevery=100000)
    yp = clf.predict(X_dev)
    full_report(y_dev, yp, tagnames)
    eval_performance(y_dev, yp, tagnames)

#### END YOUR CODE ####
# Out:
# ===== Hidden layer size 150:
# Begin SGD...
#   Seen 0 in 0.13 s
#   [0]: mean loss 1.62456
#   Seen 100000 in 2033.91 s
#   [100000]: mean loss 0.149556
#   Seen 200000 in 3996.38 s
#   [200000]: mean loss 0.106129
#   [203621]: mean loss 0.104012
# SGD complete: 203621 examples in 4105.92 seconds.
#              precision    recall  f1-score   support
#
#           O       0.97      0.98      0.98     42759
#         LOC       0.87      0.83      0.85      2094
#        MISC       0.80      0.71      0.75      1268
#         ORG       0.69      0.62      0.66      2092
#         PER       0.84      0.82      0.83      3149
#
# avg / total       0.94      0.94      0.94     51362
#
# === Performance (omitting 'O' class) ===
# Mean precision:  80.37%
# Mean recall:     76.02%
# Mean F1:         78.10%
# ===== Hidden layer size 200:
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 1.78714
#   Seen 100000 in 2001.41 s
#   [100000]: mean loss 0.147455
#   Seen 200000 in 4030.59 s
#   [200000]: mean loss 0.10544
#   [203621]: mean loss 0.107215
# SGD complete: 203621 examples in 4144.76 seconds.
#              precision    recall  f1-score   support
#
#           O       0.97      0.98      0.98     42759
#         LOC       0.82      0.86      0.84      2094
#        MISC       0.79      0.72      0.76      1268
#         ORG       0.67      0.64      0.65      2092
#         PER       0.90      0.78      0.83      3149
#
# avg / total       0.94      0.94      0.94     51362
#
# === Performance (omitting 'O' class) ===
# Mean precision:  80.75%
# Mean recall:     75.53%
# Mean F1:         77.95%
# ===== Hidden layer size 300:
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 1.69483
#   Seen 100000 in 2352.56 s
#   [100000]: mean loss 0.155039
#   Seen 200000 in 4728.56 s
#   [200000]: mean loss 0.107953
#   [203621]: mean loss 0.111801
# SGD complete: 203621 examples in 4917.63 seconds.
#              precision    recall  f1-score   support
#
#           O       0.97      0.98      0.97     42759
#         LOC       0.89      0.80      0.84      2094
#        MISC       0.76      0.72      0.74      1268
#         ORG       0.62      0.67      0.64      2092
#         PER       0.86      0.81      0.83      3149
#
# avg / total       0.94      0.94      0.94     51362
#
# === Performance (omitting 'O' class) ===
# Mean precision:
#   [170000]: mean loss 0.110854
#   [171000]: mean loss 0.114558
#   [172000]: mean loss 0.120876
#   [173000]: mean loss 0.113296
#   [174000]: mean loss 0.109119
#   [175000]: mean loss 0.113983
#   [176000]: mean loss 0.106645
#   [177000]: mean loss 0.107726
#   [178000]: mean loss 0.107466
#   [179000]: mean loss 0.114012
#   [180000]: mean loss 0.115123
#   [181000]: mean loss 0.104721
#   [182000]: mean loss 0.109047
#   [183000]: mean loss 0.113024
#   [184000]: mean loss 0.108682
#   [185000]: mean loss 0.106334
#   [186000]: mean loss 0.10834
#   [187000]: mean loss 0.10705
#   [188000]: mean loss 0.10608
#   [189000]: mean loss 0.104589
#   [190000]: mean loss 0.108417
#   [191000]: mean loss 0.110792
#   [192000]: mean loss 0.106
#   [193000]: mean loss 0.106893
#   [194000]: mean loss 0.108731
#   [195000]: mean loss 0.113128
#   [196000]: mean loss 0.10758
#   [197000]: mean loss 0.105825
#   [198000]: mean loss 0.112131
#   [199000]: mean loss 0.102962
#   Seen 200000 in 8682.78 s
#   [200000]: mean loss 0.105049
#   [201000]: mean loss 0.108183
#   [202000]: mean loss 0.111424
#   [203000]: mean loss 0.102887
#   [203621]: mean loss 0.107211
# SGD complete: 203621 examples in 8848.29 seconds.

# %% [markdown]
# ## (e): Plot Learning Curves
# The `train_sgd` function returns a list of points `(counter, cost)` giving the mean loss after that number of SGD iterations.
#
# If the model is taking too long you can cut it off by going to *Kernel->Interrupt* in the IPython menu; `train_sgd` will return the training curve so-far, and you can restart without losing your training progress.
#
# Make two plots:
#
# - Learning curve using `reg = 0.001`, and comparing the effect of changing the learning rate: run with `alpha = 0.01` and `alpha = 0.1`. Use minibatches of size 5, and train for 10,000 minibatches with `costevery=200`. Be sure to scale up your counts (x-axis) to reflect the batch size. What happens if the model tries to learn too fast? Explain why this occurs, based on the relation of SGD to the true objective.
#
# - Learning curve for your best model (print the hyperparameters in the title), as trained using your best schedule. Set `costevery` so that you get at least 100 points to plot.

# %%
##
# Plot your best learning curve here
counts, costs = zip(*traincurvebest)
figure(figsize=(6,4))
plot(5*array(counts), costs, color='b', marker='o', linestyle='-')
title(r"Learning Curve ($\alpha$=%g, $\lambda$=%g)" % (clf.alpha, clf.lreg))
xlabel("SGD Iterations"); ylabel(r"Average $J(\theta)$"); 
ylim(ymin=0, ymax=max(1.1*max(costs),3*min(costs)));
ylim(0,0.5)

# Don't change this filename!
savefig("ner.learningcurve.best.png")

# %%
k = 5
num_batches = 10000

# A random schedule of N/k minibatches of size k, sampled with replacement from the training set.
def idxiter_batches1():
    for i in xrange(num_batches):
        yield random.choice(indices, k)

clf1 = WindowMLP(wv, windowsize=3, dims=[None, 100, 5], reg=0.001, alpha=0.01)
trainingcurve1 = clf1.train_sgd(X=X_train, y=y_train, idxiter=idxiter_batches1(), printevery=50000, costevery=200)
# Out:
# Begin SGD...
#   Seen 0 in 0.17 s
#   [0]: mean loss 1.77988
#   [200]: mean loss 0.458307
#   [400]: mean loss 0.43263
#   [600]: mean loss 0.415051
#   [800]: mean loss 0.416162
#   [1000]: mean loss 0.394731
#   [1200]: mean loss 0.38793
#   [1400]: mean loss 0.389158
#   [1600]: mean loss 0.382194
#   [1800]: mean loss 0.386196
#   [2000]: mean loss 0.378089
#   [2200]: mean loss 0.368838
#   [2400]: mean loss 0.379978
#   [2600]: mean loss 0.366058
#   [2800]: mean loss 0.362414
#   [3000]: mean loss 0.35909
#   [3200]: mean loss 0.362158
#   [3400]: mean loss 0.358592
#   [3600]: mean loss 0.356091
#   [3800]: mean loss 0.35248
#   [4000]: mean loss 0.353337
#   [4200]: mean loss 0.35156
#   [4400]: mean loss 0.361819
#   [4600]: mean loss 0.34976
#   [4800]: mean loss 0.368487
#   [5000]: mean loss 0.351074
#   [5200]: mean loss 0.346439
#   [5400]: mean loss 0.344436
#   [5600]: mean loss 0.343053
#   [5800]: mean loss 0.336681
#   [6000]: mean loss 0.343293
#   [6200]: mean loss 0.335308
#   [6400]: mean loss 0.332231
#   [6600]: mean loss 0.332381
#   [6800]: mean loss 0.340364
#   [7000]: mean loss 0.340914
#   [7200]: mean loss 0.333888
#   [7400]: mean loss 0.3361
#   [7600]: mean loss 0.334077
#   [7800]: mean loss 0.334069
#   [8000]: mean loss 0.327675
#   [8200]: mean loss 0.333499
#   [8400]: mean loss 0.324635
#   [8600]: mean loss 0.34101
#   [8800]: mean loss 0.32286
#   [9000]: mean loss 0.334551
#   [9200]: mean loss 0.327452
#   [9400]: mean loss 0.322483
#   [9600]: mean loss 0.329314
#   [9800]: mean loss 0.327928
#   [10000]: mean loss 0.322276
# SGD complete: 10000 examples in 1201.87 seconds.

# %%
k = 5
num_batches = 10000

# A random schedule of N/k minibatches of size k, sampled with replacement from the training set.
def idxiter_batches1():
    for i in xrange(num_batches):
        yield random.choice(indices, k)

clf2 = WindowMLP(wv, windowsize=3, dims=[None, 100, 5], reg=0.001, alpha=0.1)
trainingcurve2 = clf2.train_sgd(X=X_train, y=y_train, idxiter=idxiter_batches1(), printevery=50000, costevery=200)
# Out:
# Begin SGD...
#   Seen 0 in 0.03 s
#   [0]: mean loss 1.77988
#   [200]: mean loss 0.715315
#   [400]: mean loss 0.840626
#   [600]: mean loss 0.788086
#   [800]: mean loss 1.16419
#   [1000]: mean loss 1.01078
#   [1200]: mean loss 1.01852
#   [1400]: mean loss 0.722265
#   [1600]: mean loss 0.971459
#   [1800]: mean loss 1.84746
#   [2000]: mean loss 1.12886
#   [2200]: mean loss 0.994072
#   [2400]: mean loss 1.47046
#   [2600]: mean loss 0.979129
#   [2800]: mean loss 1.14041
#   [3000]: mean loss 1.42977
#   [3200]: mean loss 1.17818
#   [3400]: mean loss 1.16415
#   [3600]: mean loss 1.26784
#   [3800]: mean loss 1.1642
#   [4000]: mean loss 0.960546
#   [4200]: mean loss 1.26994
#   [4400]: mean loss 1.6724
#   [4600]: mean loss 1.19917
#   [4800]: mean loss 1.59969
#   [5000]: mean loss 1.32757
#   [5200]: mean loss 1.37321
#   [5400]: mean loss 1.16525
#   [5600]: mean loss 1.02129
#   [5800]: mean loss 1.09598
#   [6000]: mean loss 1.13698
#   [6200]: mean loss 1.11974
#   [6400]: mean loss 0.864312
#   [6600]: mean loss 1.01472
#   [6800]: mean loss 1.36372
#   [7000]: mean loss 0.983747
#   [7200]: mean loss 1.1433
#   [7400]: mean loss 1.11015
#   [7600]: mean loss 1.32474
#   [7800]: mean loss 1.20619
#   [8000]: mean loss 1.5573
#   [8200]: mean loss 1.48185
#   [8400]: mean loss 0.914746
#   [8600]: mean loss 1.19966
#   [8800]: mean loss 1.07853
#   [9000]: mean loss 0.912342
#   [9200]: mean loss 1.22334
#   [9400]: mean loss 0.836153
#   [9600]: mean loss 1.4789
#   [9800]: mean loss 1.12414
#   [10000]: mean loss 0.971168
# SGD complete: 10000 examples in 1215.24 seconds.

# %%
##
# Plot comparison of learning rates here
# feel free to change the code below

figure(figsize=(6,4))
counts, costs = zip(*trainingcurve1)
plot(5*array(counts), costs, color='b', marker='o', linestyle='-', label=r"$\alpha=0.01$")
counts, costs = zip(*trainingcurve2)
plot(5*array(counts), costs, color='g', marker='o', linestyle='-', label=r"$\alpha=0.1$")
title(r"Learning Curve ($\lambda=0.001$, minibatch k=5)")
xlabel("SGD Iterations"); ylabel(r"Average $J(\theta)$"); 
ylim(ymin=0, ymax=max(1.1*max(costs),3*min(costs)));
legend()

# Don't change this filename
savefig("ner.learningcurve.comparison.png")

# %% [markdown]
# ## (f): Evaluating your model
# Evaluate the model on the dev set using your `predict` function, and compute performance metrics below!

# %%
# Predict labels on the dev set
yp = clf.predict(X_dev)
# Save predictions to a file, one per line
ner.save_predictions(yp, "dev.predicted")

# %%
from nerwindow import full_report, eval_performance
full_report(y_dev, yp, tagnames) # full report, helpful diagnostics
eval_performance(y_dev, yp, tagnames) # performance: optimize this F1
# Out:
#              precision    recall  f1-score   support
#
#           O       0.97      0.98      0.98     42759
#         LOC       0.91      0.80      0.85      2094
#        MISC       0.83      0.71      0.76      1268
#         ORG       0.72      0.64      0.67      2092
#         PER       0.84      0.86      0.85      3149
#
# avg / total       0.95      0.95      0.95     51362
#
# === Performance (omitting 'O' class) ===
# Mean precision:  82.33%
# Mean recall:     76.89%
# Mean F1:         79.39%

# %%
# Save your predictions on the test set for us to evaluate
# IMPORTANT: make sure X_test is exactly as loaded 
# from du.docs_to_windows, so that your predictions 
# line up with ours.
yptest = clf.predict(X_test)
ner.save_predictions(yptest, "test.predicted")

# %% [markdown]
# ## Part [1.1]: Probing neuron responses
#
# You might have seen some results from computer vision where the individual neurons learn to detect edges, shapes, or even [cat faces](http://googleblog.blogspot.com/2012/06/using-large-scale-brain-simulations-for.html). We're going to do the same for language.
#
# Recall that each "neuron" is essentially a logistic regression unit, with weights corresponding to rows of the corresponding matrix. So, if we have a hidden layer of dimension 100, then we can think of our matrix $W \in \mathbb{R}^{100 x 150}$ as representing 100 hidden neurons each with weights `W[i,:]` and bias `b1[i]`.
#
# ### (a): Hidden Layer, Center Word
# For now, let's just look at the center word, and ignore the rest of the window. This corresponds to columns `W[:,50:100]`, although this could change if you altered the window size for your model. For each neuron, find the top 10 words that it responds to, as measured by the dot product between `W[i,50:100]` and `L[j]`. Use the provided code to print these words and their scores for 5 neurons of your choice. In your writeup, briefly describe what you notice here.
#
# The `num_to_word` dictionary, loaded earlier, may be helpful.

# %%
# Recommended function to print scores
# scores = list of float
# words = list of str
def print_scores(scores, words):
    for i in range(len(scores)):
        print "[%d]: (%.03f) %s" % (i, scores[i], words[i])

#### YOUR CODE HERE ####
import numpy as np

neurons = [5, 7, 11, 20, 25] # change this to your chosen neurons

for i in neurons:
    print "Neuron %d" % i
    
    # W[...] is 1 x 50, L is |V| x 50
    # get the argmax indices of this:
    dots = np.dot(clf.params.W[i, 50:100], clf.sparams.L.T)
    indices = dots.argsort()[-10:][::-1]
    words = [num_to_word[i] for i in indices]
    scores = [dots[i] for i in indices]
    
    #print_scores(topscores[i], topwords[i])
    print_scores(scores, words)
    
#### END YOUR CODE ####
# Out:
# Neuron 5
# [0]: (0.992) estimated
# [1]: (0.938) lyrics
# [2]: (0.928) songs
# [3]: (0.879) albums
# [4]: (0.877) instance
# [5]: (0.836) interesting
# [6]: (0.830) recorded
# [7]: (0.827) oral
# [8]: (0.824) scores
# [9]: (0.814) example
# Neuron 7
# [0]: (7.023) [
# [1]: (5.442) let
# [2]: (5.331) more
# [3]: (5.307) caught
# [4]: (5.114) married
# [5]: (5.037) killed
# [6]: (4.979) how
# [7]: (4.952) (
# [8]: (4.938) illegal
# [9]: (4.927) n't
# Neuron 11
# [0]: (2.999) example
# [1]: (2.566) </s>
# [2]: (2.443) debut
# [3]: (2.399) album
# [4]: (2.345) extra
# [5]: (2.295) edition
# [6]: (2.288) estimated
# [7]: (2.268) score
# [8]: (2.153) formula
# [9]: (2.129) bonus
# Neuron 20
# [0]: (2.676) notably
# [1]: (2.217) e.g.
# [2]: (2.183) besides
# [3]: (2.158) depending
# [4]: (2.129) unfortunately
# [5]: (2.128) </s>
# [6]: (2.089) note
# [7]: (2.082) see
# [8]: (2.024) reasons
# [9]: (2.020) instances
# Neuron 25
# [0]: (0.566) lobby
# [1]: (0.562) 'd
# [2]: (0.557) offices
# [3]: (0.533) plans
# [4]: (0.521) suddenly
# [5]: (0.516) employees
# [6]: (0.510) chair
# [7]: (0.503) bridges
# [8]: (0.498) 'll
# [9]: (0.496) concerned

# %% [markdown]
# ### (b): Model Output, Center Word
# Now, let's do the same for the output layer. Here we only have 5 neurons, one for each class. `O` isn't very interesting, but let's look at the other four.
#
# Here things get a little more complicated: since we take a softmax, we can't just look at the neurons separately. An input could cause several of these neurons to all have a strong response, so we really need to compute the softmax output and find the strongest inputs for each class.
#
# As before, let's consider only the center word (`W[:,50:100]`). For each class `ORG`, `PER`, `LOC`, and `MISC`, find the input words that give the highest probability $P(\text{class}\ |\ \text{word})$.
#
# You'll need to do the full feed-forward computation here - for efficiency, try to express this as a matrix operation on $L$. This is the same feed-forward computation as used to predict probabilities, just with $W$ replaced by `W[:,50:100]`.
#
# As with the hidden-layer neurons, print the top 10 words and their corresponding class probabilities for each class.

# %%
#### YOUR CODE HERE ####

def softmax(x):
    input_x = x
    
    if len(x.shape) == 1:
        x = x.reshape((1, x.shape[0]))
    
    row_maxes = np.amax(x, axis=1).reshape((x.shape[0], 1))
    x = np.exp(x - row_maxes)
    row_sums = np.sum(x, axis=1).reshape((x.shape[0], 1))
    x = x / row_sums
    x = x.reshape(input_x.shape)
    
    return x

# W is (100, 50), L is (|V|, 50)
# U is (5, 100)
a = np.dot(clf.sparams.L, clf.params.W[:, 50:100].T) + clf.params.b1 # (|V|, 100)
h = tanh(a) # (|V|, 100)
y_hat = softmax(np.dot(h, clf.params.U.T) + clf.params.b2) # (|V|, 5)

for i in range(1,5):
    # take the ith column of y_hat
    probs = y_hat[:, i] # (|V|,)
    indices = probs.argsort()[-10:][::-1]
    topscores = [probs[j] for j in indices]
    topwords = [num_to_word[j] for j in indices]
    
    print "Output neuron %d: %s" % (i, num_to_tag[i])
    print_scores(topscores, topwords)
    print ""

#### END YOUR CODE ####
# Out:
# Output neuron 1: LOC
# [0]: (0.999) norway
# [1]: (0.999) iraq
# [2]: (0.997) iran
# [3]: (0.997) canary
# [4]: (0.996) zimbabwe
# [5]: (0.995) lanka
# [6]: (0.994) sweden
# [7]: (0.993) russia
# [8]: (0.993) romania
# [9]: (0.993) ukraine
#
# Output neuron 2: MISC
# [0]: (1.000) danish
# [1]: (1.000) italian
# [2]: (1.000) german
# [3]: (1.000) turkish
# [4]: (1.000) brazilian
# [5]: (1.000) egyptian
# [6]: (0.999) austrian
# [7]: (0.999) palestinians
# [8]: (0.999) israeli
# [9]: (0.999) pepsi
#
# Output neuron 3: ORG
# [0]: (1.000) microsoft
# [1]: (1.000) libraries
# [2]: (1.000) biology
# [3]: (1.000) chemistry
# [4]: (1.000) reuters
# [5]: (1.000) commons
# [6]: (1.000) computing
# [7]: (1.000) inc
# [8]: (1.000) grammar
# [9]: (1.000) catalog
#
# Output neuron 4: PER
# [0]: (1.000) thompson
# [1]: (1.000) martin
# [2]: (1.000) clinton
# [3]: (1.000) dale
# [4]: (1.000) herb
# [5]: (1.000) frank
# [6]: (1.000) innocence
# [7]: (1.000) miller
# [8]: (1.000) jim
# [9]: (1.000) daniel

# %% [markdown]
# ### (c): Model Output, Preceding Word
# Now for one final task: let's look at the preceding word. Repeat the above analysis for the output layer, but use the first part of $W$, i.e. `W[:,:50]`.
#
# Describe what you see, and include these results in your writeup.

# %%
#### YOUR CODE HERE ####

def softmax(x):
    input_x = x
    
    if len(x.shape) == 1:
        x = x.reshape((1, x.shape[0]))
    
    row_maxes = np.amax(x, axis=1).reshape((x.shape[0], 1))
    x = np.exp(x - row_maxes)
    row_sums = np.sum(x, axis=1).reshape((x.shape[0], 1))
    x = x / row_sums
    x = x.reshape(input_x.shape)
    
    return x

# W is (100, 50), L is (|V|, 50)
# U is (5, 100)
a = np.dot(clf.sparams.L, clf.params.W[:, :50].T) + clf.params.b1 # (|V|, 100)
h = tanh(a) # (|V|, 100)
y_hat = softmax(np.dot(h, clf.params.U.T) + clf.params.b2) # (|V|, 5)

for i in range(1,5):
    # take the ith column of y_hat
    probs = y_hat[:, i] # (|V|,)
    indices = probs.argsort()[-10:][::-1]
    topscores = [probs[j] for j in indices]
    topwords = [num_to_word[j] for j in indices]
    
    print "Output neuron %d: %s" % (i, num_to_tag[i])
    print_scores(topscores, topwords)
    print ""

#### END YOUR CODE ####
# Out:
# Output neuron 1: LOC
# [0]: (0.664) visited
# [1]: (0.310) born
# [2]: (0.260) occupied
# [3]: (0.241) ruled
# [4]: (0.239) governed
# [5]: (0.232) inhabited
# [6]: (0.217) extinct
# [7]: (0.206) mountains
# [8]: (0.205) lakes
# [9]: (0.181) east
#
# Output neuron 2: MISC
# [0]: (0.474) dune
# [1]: (0.420) golf
# [2]: (0.392) 'm
# [3]: (0.363) stadium
# [4]: (0.307) century
# [5]: (0.295) historic
# [6]: (0.283) catholic
# [7]: (0.265) flock
# [8]: (0.263) roman
# [9]: (0.259) la
#
# Output neuron 3: ORG
# [0]: (0.972) faire
# [1]: (0.970) &
# [2]: (0.966) corporation
# [3]: (0.966) cosmology
# [4]: (0.947) computing
# [5]: (0.947) manor
# [6]: (0.943) pantheon
# [7]: (0.942) grammar
# [8]: (0.937) wizard
# [9]: (0.933) math
#
# Output neuron 4: PER
# [0]: (1.000) adam
# [1]: (1.000) peter
# [2]: (1.000) alexander
# [3]: (1.000) m.
# [4]: (1.000) aunt
# [5]: (1.000) h.
# [6]: (1.000) roger
# [7]: (0.999) john
# [8]: (0.999) jean
# [9]: (0.999) charles
